# %%
# !pip3 install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/0b/34/a01250ac1fc9bf9161e07956d2d580413106ce02d5591470130a25c599e3/redis-5.0.1-py3-none-any.whl.metadata
#   Downloading redis-5.0.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: requests>=2.25.0 in /opt/homebrew/lib/python3.11/site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /opt/homebrew/lib/python3.11/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/homebrew/lib/python3.11/site-packages (from spotipy) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2023.5.7)
# Downloading redis-5.0.1-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.1 spotipy-2.23.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="", 
                                                      client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager= client_credentials_manager)

# %%
playlist_url = "https://open.spotify.com/playlist/37i9dQZEVXbMWDif5SCBJq"

# %%
uri = playlist_url.split("/")[-1]

# %%
data = sp.playlist_tracks(uri)

# %%
album_list=[]
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'album_name':album_name,'album_release_date':album_release_date,'album_total_tracks':album_total_tracks,
                     'album_url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '73vfz6Szer7i3GFIesix6l',
#   'album_name': 'Tu hai kahan',
#   'album_release_date': '2023-10-16',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/73vfz6Szer7i3GFIesix6l'},
#  {'album_id': '3WLJmMZUeDOuERFAk1Mxs6',
#   'album_name': 'Jawan',
#   'album_release_date': '2023-09-05',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/3WLJmMZUeDOuERFAk1Mxs6'},
#  {'album_id': '3tNH9Fp4dm3qa3Kr4cv5uJ',
#   'album_name': 'One Love',
#   'album_release_date': '2023-08-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3tNH9Fp4dm3qa3Kr4cv5uJ'},
#  {'album_id': '1wt2WZBZZ9GhM0AC61l7SS',
#   'album_name': 'Heeriye (feat. Arijit Singh)',
#   'album_release_date': '2023-07-25',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1wt2WZBZZ9GhM0AC61l7SS'},
#  {'album_id': '3BGU0BqGwBkYDHpfCWFm7I',
#   'album_name': 'Making Memories',
#   'album_release_date': '2023-08-18',
#   'album_total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/3BGU0BqGwBkYDHpfCWFm7I'},
#  {'album_id': '0qOjC3f9sN8JWr1SOz7m9Z',
#   'album_name': 'Ordinary Person (From "Leo")',
#   'album_release_date': '2023-10-24',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0qOjC3f9sN8JWr1SOz7m9Z'},
#  {'album_id': '5AivaZj0CiQJoDWqVH2pbh',
#   'album_name': 'Still Rollin',
#   'album_release_date': '2023-05-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/5AivaZj0CiQJoDWqVH2pbh'},
#  {'album_id': '2nZKDF0ZFy0Pv7uMakAwZh',
#   'album_name': 'Leo (Original Motion Picture Soundtrack)',
#   'album_release_date': '2023-10-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/2nZKDF0ZFy0Pv7uMakAwZh'},
#  {'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'album_name': 'Brahmastra (Original Motion Picture Soundtrack)',
#   'album_release_date': '2022-10-06',
#   'album_total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/4kIPlpwEZBK9JaI9pZHe79'},
#  {'album_id': '2nZKDF0ZFy0Pv7uMakAwZh',
#   'album_name': 'Leo (Original Motion Picture Soundtrack)',
#   'album_release_date': '2023-10-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/2nZKDF0ZFy0Pv7uMakAwZh'},
#  {'album_id': '0YzF0ImdBeODiCWejSDndM',
#   'album_name': 'Dard',
#   'album_release_date': '2023-08-09',
#   'album_total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/0YzF0ImdBeODiCWejSDndM'},
#  {'album_id': '0kZKLq2WZQWvXvbxvK6YoC',
#   'album_name': 'Janiye (from the Netflix Film "Chor Nikal Ke Bhaga")',
#   'album_release_date': '2023-03-17',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0kZKLq2WZQWvXvbxvK6YoC'},
#  {'album_id': '15CyNDuGY5fsG0Hn9rjnpG',
#   'album_name': 'Champagne Talk',
#   'album_release_date': '2022-10-12',
#   'album_total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/15CyNDuGY5fsG0Hn9rjnpG'},
#  {'album_id': '30eM1PJ8qLZJeEykhcje0j',
#   'album_name': 'With You',
#   'album_release_date': '2023-08-11',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/30eM1PJ8qLZJeEykhcje0j'},
#  {'album_id': '7Co0Nyse7oM3Us1KCulBpn',
#   'album_name': 'Chale Jaana Phir (Humko Tere Bina)',
#   'album_release_date': '2023-04-06',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7Co0Nyse7oM3Us1KCulBpn'},
#  {'album_id': '4mrXgKhegKi7Ol4pdN4z3Q',
#   'album_name': 'What Jhumka ? (From "Rocky Aur Rani Kii Prem Kahaani")',
#   'album_release_date': '2023-07-12',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4mrXgKhegKi7Ol4pdN4z3Q'},
#  {'album_id': '1skD49xUwXnHLMrlEKTo6j',
#   'album_name': 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke") - Single',
#   'album_release_date': '2023-05-16',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1skD49xUwXnHLMrlEKTo6j'},
#  {'album_id': '5Wm1nhxZqx7i0Hp6ZBqe9T',
#   'album_name': 'Love Forever With Arijit Singh',
#   'album_release_date': '2017-06-07',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/5Wm1nhxZqx7i0Hp6ZBqe9T'},
#  {'album_id': '0cUSfUJILJ9I38bntZKSLq',
#   'album_name': 'Khalasi | Coke Studio Bharat',
#   'album_release_date': '2023-07-05',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0cUSfUJILJ9I38bntZKSLq'},
#  {'album_id': '5ITQeRYoVu4qRdo9TUTuuR',
#   'album_name': '9:45',
#   'album_release_date': '2023-03-10',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5ITQeRYoVu4qRdo9TUTuuR'},
#  {'album_id': '7F8VISoJUWFEY57b66QZxC',
#   'album_name': 'Hass Hass',
#   'album_release_date': '2023-10-26',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7F8VISoJUWFEY57b66QZxC'},
#  {'album_id': '7khRLZe8P6XcUoRgOa3nnf',
#   'album_name': 'Malang Sajna',
#   'album_release_date': '2022-12-19',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7khRLZe8P6XcUoRgOa3nnf'},
#  {'album_id': '7BE0KM7dc0f4MX6Kc6kCuN',
#   'album_name': 'Tum Kya Mile (From "Rocky Aur Rani Kii Prem Kahaani")',
#   'album_release_date': '2023-06-28',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7BE0KM7dc0f4MX6Kc6kCuN'},
#  {'album_id': '0zRUzTXH7GtGLxt6uVdARD',
#   'album_name': 'Jailer (Original Motion Picture Soundtrack)',
#   'album_release_date': '2023-07-28',
#   'album_total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/0zRUzTXH7GtGLxt6uVdARD'},
#  {'album_id': '3IbKcMtNRze5t0ANwdp45H',
#   'album_name': 'Desi Kalakaar',
#   'album_release_date': '2014-09-26',
#   'album_total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/3IbKcMtNRze5t0ANwdp45H'},
#  {'album_id': '5Zcgog7sQ79ISF32y9nABU',
#   'album_name': 'No Love',
#   'album_release_date': '2022-02-22',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5Zcgog7sQ79ISF32y9nABU'},
#  {'album_id': '3I8PdIhk6pNm8Kv0HiF14V',
#   'album_name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")',
#   'album_release_date': '2019-05-31',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3I8PdIhk6pNm8Kv0HiF14V'},
#  {'album_id': '1N9rGbn2M9lzU6YcJ6081E',
#   'album_name': 'Manjha',
#   'album_release_date': '2020-03-17',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1N9rGbn2M9lzU6YcJ6081E'},
#  {'album_id': '5AivaZj0CiQJoDWqVH2pbh',
#   'album_name': 'Still Rollin',
#   'album_release_date': '2023-05-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/5AivaZj0CiQJoDWqVH2pbh'},
#  {'album_id': '7pFrr9ypVrxpZNF97YUQjK',
#   'album_name': 'Asal Mein',
#   'album_release_date': '2020-02-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7pFrr9ypVrxpZNF97YUQjK'},
#  {'album_id': '7zvmmYySo3FPuwEiKv7xSF',
#   'album_name': 'NEW LIFE',
#   'album_release_date': '2023-10-18',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/7zvmmYySo3FPuwEiKv7xSF'},
#  {'album_id': '0azGrKHPYvl2MEKwQFfbV2',
#   'album_name': 'Mi Amor',
#   'album_release_date': '2022-09-30',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0azGrKHPYvl2MEKwQFfbV2'},
#  {'album_id': '3rOSq53b9Cv7ygKe5NwKNJ',
#   'album_name': 'White Brown Black',
#   'album_release_date': '2022-12-09',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3rOSq53b9Cv7ygKe5NwKNJ'},
#  {'album_id': '4QCM8VlhhlwZtQ2Ew7gtIg',
#   'album_name': 'Pal',
#   'album_release_date': '2018-09-14',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4QCM8VlhhlwZtQ2Ew7gtIg'},
#  {'album_id': '2nZKDF0ZFy0Pv7uMakAwZh',
#   'album_name': 'Leo (Original Motion Picture Soundtrack)',
#   'album_release_date': '2023-10-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/2nZKDF0ZFy0Pv7uMakAwZh'},
#  {'album_id': '4GEXGGOjUBuSHR4KgaSngh',
#   'album_name': 'Tere Vaaste (From "Zara Hatke Zara Bachke") - Single',
#   'album_release_date': '2023-05-22',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4GEXGGOjUBuSHR4KgaSngh'},
#  {'album_id': '1lZk7TnMgvS3mSlfeWW1b3',
#   'album_name': 'Tere Hawaale (From "Laal Singh Chaddha")',
#   'album_release_date': '2022-08-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1lZk7TnMgvS3mSlfeWW1b3'},
#  {'album_id': '6AJaDEafyyyWWXHZQtcFGe',
#   'album_name': 'Chaand Baaliyan',
#   'album_release_date': '2020-03-28',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6AJaDEafyyyWWXHZQtcFGe'},
#  {'album_id': '4myrjFfjoaxINiIB3TR7AO',
#   'album_name': 'Kalaastar (From "Honey 3.0")',
#   'album_release_date': '2023-10-15',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4myrjFfjoaxINiIB3TR7AO'},
#  {'album_id': '5uAi4ZZc7zRdd6PsKNcJXO',
#   'album_name': 'Tere Pyaar Mein (From "Tu Jhoothi Main Makkaar")',
#   'album_release_date': '2023-02-01',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5uAi4ZZc7zRdd6PsKNcJXO'},
#  {'album_id': '5eF8So0MxcSwx5mWSG93QE',
#   'album_name': 'The Carnival',
#   'album_release_date': '2020-09-21',
#   'album_total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/5eF8So0MxcSwx5mWSG93QE'},
#  {'album_id': '2DKSZvMj7Da6rzNVPMgREj',
#   'album_name': 'Raataan Lambiyan (From "Shershaah")',
#   'album_release_date': '2021-07-30',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2DKSZvMj7Da6rzNVPMgREj'},
#  {'album_id': '3BGU0BqGwBkYDHpfCWFm7I',
#   'album_name': 'Making Memories',
#   'album_release_date': '2023-08-18',
#   'album_total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/3BGU0BqGwBkYDHpfCWFm7I'},
#  {'album_id': '4OYdTHNgjhXzgVjbqsb0tO',
#   'album_name': 'Jab We Met',
#   'album_release_date': '2007-09-21',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/4OYdTHNgjhXzgVjbqsb0tO'},
#  {'album_id': '1ncyKqyZae6DoyjYaV9LmS',
#   'album_name': 'Kaise Hua (From "Kabir Singh")',
#   'album_release_date': '2019-06-13',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1ncyKqyZae6DoyjYaV9LmS'},
#  {'album_id': '0Z1zYMwJRpvq0d9rdqTOYo',
#   'album_name': 'Ranjha (From "Shershaah")',
#   'album_release_date': '2021-08-05',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0Z1zYMwJRpvq0d9rdqTOYo'},
#  {'album_id': '3JiVWzoQqLwmH8DcayvdQ6',
#   'album_name': 'Hayyoda (From "Jawan")',
#   'album_release_date': '2023-08-14',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3JiVWzoQqLwmH8DcayvdQ6'},
#  {'album_id': '6IXfWhC7omotM4lt0ROmEr',
#   'album_name': 'Love Aaj Kal (Original Motion Picture Soundtrack)',
#   'album_release_date': '2020-02-14',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/6IXfWhC7omotM4lt0ROmEr'},
#  {'album_id': '6BHlJhCk1vjCG6hqTG2SFV',
#   'album_name': 'Kahani Suno 2.0',
#   'album_release_date': '2022-05-31',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6BHlJhCk1vjCG6hqTG2SFV'},
#  {'album_id': '0vEzErGiuiczFnmuOD35sB',
#   'album_name': 'Laado',
#   'album_release_date': '2023-08-30',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0vEzErGiuiczFnmuOD35sB'}]

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict= {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '2cjQTf2J5yCaNY8qHpW855',
#   'artist_name': 'AUR',
#   'external_url': 'https://api.spotify.com/v1/artists/2cjQTf2J5yCaNY8qHpW855'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '19LIHDDSHBD5NyYHI3gpzB',
#   'artist_name': 'Shilpa Rao',
#   'external_url': 'https://api.spotify.com/v1/artists/19LIHDDSHBD5NyYHI3gpzB'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '74OaRjmyh0XyRZsQQQ5l7c',
#   'artist_name': 'Jasleen Royal',
#   'external_url': 'https://api.spotify.com/v1/artists/74OaRjmyh0XyRZsQQQ5l7c'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '3NHwwyb1coYa5cLyI72xSk',
#   'artist_name': 'Dulquer Salmaan',
#   'external_url': 'https://api.spotify.com/v1/artists/3NHwwyb1coYa5cLyI72xSk'},
#  {'artist_id': '6DARBhWbfcS9E4yJzcliqQ',
#   'artist_name': 'Karan Aujla',
#   'external_url': 'https://api.spotify.com/v1/artists/6DARBhWbfcS9E4yJzcliqQ'},
#  {'artist_id': '3nqS8jzqmsPKFJTp0BOIel',
#   'artist_name': 'Ikky',
#   'external_url': 'https://api.spotify.com/v1/artists/3nqS8jzqmsPKFJTp0BOIel'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '3tPQOjkxO3mrYrrgkTeXgH',
#   'artist_name': 'Nikhita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/3tPQOjkxO3mrYrrgkTeXgH'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '0fhunuOz2OuOEr3YK5ctSm',
#   'artist_name': 'Thalapathy Vijay',
#   'external_url': 'https://api.spotify.com/v1/artists/0fhunuOz2OuOEr3YK5ctSm'},
#  {'artist_id': '4b1WCDqAVVgxK7KozLkOqc',
#   'artist_name': 'Asal Kolaar',
#   'external_url': 'https://api.spotify.com/v1/artists/4b1WCDqAVVgxK7KozLkOqc'},
#  {'artist_id': '2GoeZ0qOTt6kjsWW4eA6LS',
#   'artist_name': 'Darshan Raval',
#   'external_url': 'https://api.spotify.com/v1/artists/2GoeZ0qOTt6kjsWW4eA6LS'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artist_id': '15UQcr22jcc6DJjy3sLv3J',
#   'artist_name': 'Rashmeet Kaur',
#   'external_url': 'https://api.spotify.com/v1/artists/15UQcr22jcc6DJjy3sLv3J'},
#  {'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '6LEG9Ld1aLImEFEVHdWNSB',
#   'artist_name': 'AP Dhillon',
#   'external_url': 'https://api.spotify.com/v1/artists/6LEG9Ld1aLImEFEVHdWNSB'},
#  {'artist_id': '6KozIqto3bkoQp4lksicOA',
#   'artist_name': 'Denny',
#   'external_url': 'https://api.spotify.com/v1/artists/6KozIqto3bkoQp4lksicOA'},
#  {'artist_id': '5wTLUHTynSSD53c7S9XEdr',
#   'artist_name': 'Rahul Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wTLUHTynSSD53c7S9XEdr'},
#  {'artist_id': '52XgeWw24o4klNdfwvB0Vx',
#   'artist_name': 'Kunaal Vermaa',
#   'external_url': 'https://api.spotify.com/v1/artists/52XgeWw24o4klNdfwvB0Vx'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '00sCATpEvwH48ays7PlQFU',
#   'artist_name': 'Jonita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/00sCATpEvwH48ays7PlQFU'},
#  {'artist_id': '0lMa3YTHqQnDDTBaxAV7LK',
#   'artist_name': 'Ranveer Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/0lMa3YTHqQnDDTBaxAV7LK'},
#  {'artist_id': '5Uvn1P3OFu268QovsUAnDu',
#   'artist_name': 'Madan Mohan',
#   'external_url': 'https://api.spotify.com/v1/artists/5Uvn1P3OFu268QovsUAnDu'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artist_name': 'Sachin-Jigar',
#   'external_url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '7uw9rkZ9mxuSBuURy86ERR',
#   'artist_name': 'Amitabha Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/7uw9rkZ9mxuSBuURy86ERR'},
#  {'artist_id': '3gBKY0y3dFFVRqicLnVZYz',
#   'artist_name': 'Alka Yagnik',
#   'external_url': 'https://api.spotify.com/v1/artists/3gBKY0y3dFFVRqicLnVZYz'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '68BDWvc511MC0b6eAmH7gW',
#   'artist_name': 'Aditya Gadhvi',
#   'external_url': 'https://api.spotify.com/v1/artists/68BDWvc511MC0b6eAmH7gW'},
#  {'artist_id': '4bvGDTEPFnllKiJaEZGuXk',
#   'artist_name': 'Achint',
#   'external_url': 'https://api.spotify.com/v1/artists/4bvGDTEPFnllKiJaEZGuXk'},
#  {'artist_id': '0VAIiNSKG4DWkSaIy5qWz1',
#   'artist_name': 'Prabh Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/0VAIiNSKG4DWkSaIy5qWz1'},
#  {'artist_id': '47SaOSOqcrxSJNZUuqpLuu',
#   'artist_name': 'Jay Trak',
#   'external_url': 'https://api.spotify.com/v1/artists/47SaOSOqcrxSJNZUuqpLuu'},
#  {'artist_id': '2FKWNmZWDBZR4dE5KX4plR',
#   'artist_name': 'Diljit Dosanjh',
#   'external_url': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR'},
#  {'artist_id': '5WUlDfRSoLAfcVSX1WnrxN',
#   'artist_name': 'Sia',
#   'external_url': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN'},
#  {'artist_id': '2sWf9Tj6EsTxURcgil3NTG',
#   'artist_name': 'Greg Kurstin',
#   'external_url': 'https://api.spotify.com/v1/artists/2sWf9Tj6EsTxURcgil3NTG'},
#  {'artist_id': '6WOdPJmexxFINcKMkP2jMG',
#   'artist_name': 'Sachet Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG'},
#  {'artist_id': '1E6arsXf5Fgsnv9YpSzjpE',
#   'artist_name': 'Parampara Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '1SyKki7JI1AZNKwgNMkn25',
#   'artist_name': 'Sachet-Parampara',
#   'external_url': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '6sXT8Cggm4tmoxhVjaUVs0',
#   'artist_name': 'Super Subu',
#   'external_url': 'https://api.spotify.com/v1/artists/6sXT8Cggm4tmoxhVjaUVs0'},
#  {'artist_id': '7uIbLdzzSEqnX0Pkrb56cR',
#   'artist_name': 'Yo Yo Honey Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/7uIbLdzzSEqnX0Pkrb56cR'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '09UmIX92EUH9hAK4bxvHx6',
#   'artist_name': 'Mithoon',
#   'external_url': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '2GoeZ0qOTt6kjsWW4eA6LS',
#   'artist_name': 'Darshan Raval',
#   'external_url': 'https://api.spotify.com/v1/artists/2GoeZ0qOTt6kjsWW4eA6LS'},
#  {'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '74RGMjbSsFv5RLj8wVx9Yv',
#   'artist_name': 'Sharn',
#   'external_url': 'https://api.spotify.com/v1/artists/74RGMjbSsFv5RLj8wVx9Yv'},
#  {'artist_id': '6nAMu7pGqdwUSsGMZPUvSk',
#   'artist_name': '40k',
#   'external_url': 'https://api.spotify.com/v1/artists/6nAMu7pGqdwUSsGMZPUvSk'},
#  {'artist_id': '1i31OYo0s5VoMCaMRJFZkJ',
#   'artist_name': 'The Paul',
#   'external_url': 'https://api.spotify.com/v1/artists/1i31OYo0s5VoMCaMRJFZkJ'},
#  {'artist_id': '4qjiRRFcM4WZ0aJ3IHdWPN',
#   'artist_name': 'Avvy Sra',
#   'external_url': 'https://api.spotify.com/v1/artists/4qjiRRFcM4WZ0aJ3IHdWPN'},
#  {'artist_id': '6DARBhWbfcS9E4yJzcliqQ',
#   'artist_name': 'Karan Aujla',
#   'external_url': 'https://api.spotify.com/v1/artists/6DARBhWbfcS9E4yJzcliqQ'},
#  {'artist_id': '5gZhfbckaWo89OzDSk3gdT',
#   'artist_name': 'Jaani',
#   'external_url': 'https://api.spotify.com/v1/artists/5gZhfbckaWo89OzDSk3gdT'},
#  {'artist_id': '2zvJLk0gTH7r7A5Q6X5Bq8',
#   'artist_name': 'Javed-Mohsin',
#   'external_url': 'https://api.spotify.com/v1/artists/2zvJLk0gTH7r7A5Q6X5Bq8'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '52XgeWw24o4klNdfwvB0Vx',
#   'artist_name': 'Kunaal Vermaa',
#   'external_url': 'https://api.spotify.com/v1/artists/52XgeWw24o4klNdfwvB0Vx'},
#  {'artist_id': '5DNHuR9u8DFVasxQZgREO5',
#   'artist_name': 'Prashant Ingole',
#   'external_url': 'https://api.spotify.com/v1/artists/5DNHuR9u8DFVasxQZgREO5'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artist_name': 'Sachin-Jigar',
#   'external_url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artist_id': '4gzrZDyL5gYiROkv27pYKx',
#   'artist_name': 'Varun Jain',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzrZDyL5gYiROkv27pYKx'},
#  {'artist_id': '6WixbETKEXH0xBf0OB9kRB',
#   'artist_name': 'Shadab Faridi',
#   'external_url': 'https://api.spotify.com/v1/artists/6WixbETKEXH0xBf0OB9kRB'},
#  {'artist_id': '38IHJBGBuaYXHEkIQd4DtF',
#   'artist_name': 'Altamash Faridi',
#   'external_url': 'https://api.spotify.com/v1/artists/38IHJBGBuaYXHEkIQd4DtF'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '19LIHDDSHBD5NyYHI3gpzB',
#   'artist_name': 'Shilpa Rao',
#   'external_url': 'https://api.spotify.com/v1/artists/19LIHDDSHBD5NyYHI3gpzB'},
#  {'artist_id': '4wwYGgSpeBtvk5WX6HBqzw',
#   'artist_name': 'Aditya A',
#   'external_url': 'https://api.spotify.com/v1/artists/4wwYGgSpeBtvk5WX6HBqzw'},
#  {'artist_id': '7uIbLdzzSEqnX0Pkrb56cR',
#   'artist_name': 'Yo Yo Honey Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/7uIbLdzzSEqnX0Pkrb56cR'},
#  {'artist_id': '0N2lT1m7rG0klYHZrkyMPw',
#   'artist_name': 'Rony Ajnali',
#   'external_url': 'https://api.spotify.com/v1/artists/0N2lT1m7rG0klYHZrkyMPw'},
#  {'artist_id': '4r4r2gGaA74pul0n6FiRsE',
#   'artist_name': 'Gill Machhrai',
#   'external_url': 'https://api.spotify.com/v1/artists/4r4r2gGaA74pul0n6FiRsE'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '3tPQOjkxO3mrYrrgkTeXgH',
#   'artist_name': 'Nikhita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/3tPQOjkxO3mrYrrgkTeXgH'},
#  {'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
#   'artist_name': 'Jubin Nautiyal',
#   'external_url': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa'},
#  {'artist_id': '1sVmXkzX2ukc6QvasrDBES',
#   'artist_name': 'Asees Kaur',
#   'external_url': 'https://api.spotify.com/v1/artists/1sVmXkzX2ukc6QvasrDBES'},
#  {'artist_id': '6DARBhWbfcS9E4yJzcliqQ',
#   'artist_name': 'Karan Aujla',
#   'external_url': 'https://api.spotify.com/v1/artists/6DARBhWbfcS9E4yJzcliqQ'},
#  {'artist_id': '3nqS8jzqmsPKFJTp0BOIel',
#   'artist_name': 'Ikky',
#   'external_url': 'https://api.spotify.com/v1/artists/3nqS8jzqmsPKFJTp0BOIel'},
#  {'artist_id': '5TvdGhdmRObqOkU6eGfXb5',
#   'artist_name': 'Preston Pablo',
#   'external_url': 'https://api.spotify.com/v1/artists/5TvdGhdmRObqOkU6eGfXb5'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '5GnnSrwNCGyfAU4zuIytiS',
#   'artist_name': 'Mohit Chauhan',
#   'external_url': 'https://api.spotify.com/v1/artists/5GnnSrwNCGyfAU4zuIytiS'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artist_id': '74OaRjmyh0XyRZsQQQ5l7c',
#   'artist_name': 'Jasleen Royal',
#   'external_url': 'https://api.spotify.com/v1/artists/74OaRjmyh0XyRZsQQQ5l7c'},
#  {'artist_id': '56SjZARoEvag3RoKWIb16j',
#   'artist_name': 'B Praak',
#   'external_url': 'https://api.spotify.com/v1/artists/56SjZARoEvag3RoKWIb16j'},
#  {'artist_id': '0bRPtPZQkWHeG7MGk9eWlh',
#   'artist_name': 'Romy',
#   'external_url': 'https://api.spotify.com/v1/artists/0bRPtPZQkWHeG7MGk9eWlh'},
#  {'artist_id': '4nJ0kto93jDLHQKmpGeYS8',
#   'artist_name': 'Anvita Dutt',
#   'external_url': 'https://api.spotify.com/v1/artists/4nJ0kto93jDLHQKmpGeYS8'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '5PMrnGmlpH0l7Uc9DnnatM',
#   'artist_name': 'Priya Mali',
#   'external_url': 'https://api.spotify.com/v1/artists/5PMrnGmlpH0l7Uc9DnnatM'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '1n9EM0Y4A89vuRiA93gSS9',
#   'artist_name': 'Kaifi Khalil',
#   'external_url': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9'},
#  {'artist_id': '5WZViOJ21095FUcGPMpKFF',
#   'artist_name': 'MC SQUARE',
#   'external_url': 'https://api.spotify.com/v1/artists/5WZViOJ21095FUcGPMpKFF'},
#  {'artist_id': '597A6e3D22Vq4gxyh4mUjh',
#   'artist_name': 'Hiten',
#   'external_url': 'https://api.spotify.com/v1/artists/597A6e3D22Vq4gxyh4mUjh'}]

# %%
song_list=[]
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'song_duration':song_duration,'song_url':song_url,'song_popularity':song_popularity,
                   'song_added':song_added, 'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                    album_name album_release_date  \
# 0  73vfz6Szer7i3GFIesix6l                  Tu hai kahan         2023-10-16
# 1  3WLJmMZUeDOuERFAk1Mxs6                         Jawan         2023-09-05
# 2  3tNH9Fp4dm3qa3Kr4cv5uJ                      One Love         2023-08-18
# 3  1wt2WZBZZ9GhM0AC61l7SS  Heeriye (feat. Arijit Singh)         2023-07-25
# 4  3BGU0BqGwBkYDHpfCWFm7I               Making Memories         2023-08-18
#
#    album_total_tracks                                          album_url
# 0                   1  https://open.spotify.com/album/73vfz6Szer7i3GF...
# 1                   7  https://open.spotify.com/album/3WLJmMZUeDOuERF...
# 2                   1  https://open.spotify.com/album/3tNH9Fp4dm3qa3K...
# 3                   1  https://open.spotify.com/album/1wt2WZBZZ9GhM0A...
# 4                   9  https://open.spotify.com/album/3BGU0BqGwBkYDHp...

# %%
song_df.head()
# Out:
#                   song_id                     song_name  song_duration  \
# 0  3zSSCPpLZ5Oc8nelhhGjKz                  Tu hai kahan         263184
# 1  3xMHXmedL5Rvfxmiar9Ryv                       Chaleya         200373
# 2  5ZLkihi6DVsHwDL3B8ym1t                      One Love         159222
# 3  5PUXKVVVQ74C3gl5vKy9Li  Heeriye (feat. Arijit Singh)         194857
# 4  0YQJoDL6f46J0n1rOVkpxJ                        Softly         155161
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/3zSSCPpLZ5Oc8ne...               86
# 1  https://open.spotify.com/track/3xMHXmedL5Rvfxm...               84
# 2  https://open.spotify.com/track/5ZLkihi6DVsHwDL...               86
# 3  https://open.spotify.com/track/5PUXKVVVQ74C3gl...               89
# 4  https://open.spotify.com/track/0YQJoDL6f46J0n1...               84
#
#              song_added                album_id               artist_id
# 0  2023-11-10T09:09:01Z  73vfz6Szer7i3GFIesix6l  2cjQTf2J5yCaNY8qHpW855
# 1  2023-11-10T09:09:01Z  3WLJmMZUeDOuERFAk1Mxs6  4zCH9qm4R2DADamUHMCa6O
# 2  2023-11-10T09:09:01Z  3tNH9Fp4dm3qa3Kr4cv5uJ  5r3wPya2PpeTTsXsGhQU8O
# 3  2023-11-10T09:09:01Z  1wt2WZBZZ9GhM0AC61l7SS  74OaRjmyh0XyRZsQQQ5l7c
# 4  2023-11-10T09:09:01Z  3BGU0BqGwBkYDHpfCWFm7I  6DARBhWbfcS9E4yJzcliqQ

# %%
artist_df.head()
# Out:
#                 artist_id          artist_name  \
# 0  2cjQTf2J5yCaNY8qHpW855                  AUR
# 1  4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander
# 2  4YRxDV8wJFPHPTeXepOstw         Arijit Singh
# 3  19LIHDDSHBD5NyYHI3gpzB           Shilpa Rao
# 4  0m3D4grap8VFSzbJMqgNVk               Kumaar
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/2cjQTf2J5yC...
# 1  https://api.spotify.com/v1/artists/4zCH9qm4R2D...
# 2  https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 3  https://api.spotify.com/v1/artists/19LIHDDSHBD...
# 4  https://api.spotify.com/v1/artists/0m3D4grap8V...

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
